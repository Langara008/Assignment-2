# %% [markdown]
# <a href="https://colab.research.google.com/github/Langara008/Assignment-2/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
wainaina = pd.read_csv('/content/Student enrollment data.csv')
print("Shape of the dataset:", wainaina.shape)
wainaina.head(10)
# Out:
# Shape of the dataset: (11, 10)
#    No      Name  Age   Gender Location  GPA  Attendance records %  \
# 0   1   Derrick    20    Male  Nairobi    25                  72%
# 1   2   Natasha    20  Female   Kitale    30                  45%
# 2   3    Victor    21    Male  Nairobi    23                  60%
# 3   4    Stacey    19  Female  Mombasa    24                  55%
# 4   5   Fidelis    22    Male   Kitale    22                  70%
# 5   6  Lawrence    21    Male  Nairobi    24                  78%
# 6   7     Diana    20  Female  Nairobi    30                  75%
# 7   8    Sharon    20  Female  Nairobi    21                  60%
# 8   9     Fiona    21  Female     Embu    20                  55%
# 9  10   Denzzel    22    Male  Mombasa    22                  80%
#
#    Extracurricular activities  Program Intrest Test Score
# 0                           2                1        65%
# 1                           1                2        78%
# ...

# %%
import pandas as pd
wainaina = pd.read_csv('/content/Student enrollment data.csv')
data=wainaina.loc[:,['Program Intrest','Test Score']]
data.head(10)
# Out:
#    Program Intrest Test Score
# 0                1        65%
# 1                2        78%
# 2                2        75%
# 3                3        68%
# 4                1        89%
# 5                2        80%
# 6                1        60%
# 7                2        71%
# 8                1        70%
# 9                1        72%

# %%
import pandas as pd
import matplotlib.pyplot as plt
wainaina = pd.read_csv('/content/Student enrollment data.csv')
wainaina.plot(x='Test Score',y='Program Intrest',style='o')
plt.xlabel('Test Score')
plt.ylabel('Program Intrest')
plt.show()

# %%
import pandas as pd
wainaina = pd.read_csv('/content/Student enrollment data.csv')
x=pd.DataFrame(data['Test Score'])
y=pd.DataFrame(data['Program Intrest'])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
wainaina = pd.read_csv('/content/Student enrollment data.csv')
x=pd.DataFrame(data['Test Score'])
y=pd.DataFrame(data['Program Intrest'])
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8, 1)
# (3, 1)
# (8, 1)
# (3, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-6abd9ba5ffc9> in <cell line: 3>()
#       1 from sklearn.linear_model import LinearRegression
#       2 regressor=LinearRegression()
# ----> 3 regressor.fit(X_train,y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# ...
